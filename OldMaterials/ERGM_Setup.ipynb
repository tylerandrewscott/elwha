# %%
import csv

# %%
# %load_ext rmagic

# %%
import pandas as pd

# %%
df = pd.read_csv('Group.All.Dat.csv')
emaildf=pd.DataFrame(df,columns=['GroupID','ORG','email'])
meetdf=pd.DataFrame(df,columns=['GroupID','ORG','meet'])
eventdf=pd.DataFrame(df,columns=['GroupID','ORG','event'])
projdf=pd.DataFrame(df,columns=['GroupID','ORG','proj'])
readdf=pd.DataFrame(df,columns=['GroupID','ORG','read'])
writedf=pd.DataFrame(df,columns=['GroupID','ORG','write'])
otherdf=pd.DataFrame(df,columns=['GroupID','ORG','other'])

emaildf.drop(emaildf.columns[0],1)
ts = emaildf
tt = ts[ts.email==1]
tt.groupby('GroupID')
cross = pd.crosstab(tt.GroupID,tt.ORG)
dff = pd.DataFrame(columns=('ORG1','ORG2','Count'))
for i in range(0,cross.shape[0]):
#for i in range(17,18):
    ff = pd.DataFrame(cross.iloc[i,][cross.iloc[i,]==1])
    for j in range(0,cross.iloc[i,][cross.iloc[i,]==1].shape[0]-1):
        for k in range(0,cross.iloc[i,][cross.iloc[i,]==1].shape[0]-1):
            #temp = pd.DataFrame(columns=('ORG1','ORG2','Count')
            temp = {'ORG1':ff.index[j], 'ORG2':ff.index[k], 'Count':1}
            dff = dff.append(temp,ignore_index=True)
dffemail = dff

eventdf.drop(eventdf.columns[0],1)
ts = eventdf
tt = ts[ts.event==1]
tt.groupby('GroupID')
cross = pd.crosstab(tt.GroupID,tt.ORG)
dff = pd.DataFrame(columns=('ORG1','ORG2','Count'))
for i in range(0,cross.shape[0]):
#for i in range(17,18):
    ff = pd.DataFrame(cross.iloc[i,][cross.iloc[i,]==1])
    for j in range(0,cross.iloc[i,][cross.iloc[i,]==1].shape[0]-1):
        for k in range(0,cross.iloc[i,][cross.iloc[i,]==1].shape[0]-1):
            #temp = pd.DataFrame(columns=('ORG1','ORG2','Count')
            temp = {'ORG1':ff.index[j], 'ORG2':ff.index[k], 'Count':1}
            dff = dff.append(temp,ignore_index=True)
dffevent = dff

meetdf.drop(meetdf.columns[0],1)
ts = meetdf
tt = ts[ts.meet==1]
tt.groupby('GroupID')
cross = pd.crosstab(tt.GroupID,tt.ORG)
dff = pd.DataFrame(columns=('ORG1','ORG2','Count'))
for i in range(0,cross.shape[0]):
#for i in range(17,18):
    ff = pd.DataFrame(cross.iloc[i,][cross.iloc[i,]==1])
    for j in range(0,cross.iloc[i,][cross.iloc[i,]==1].shape[0]-1):
        for k in range(0,cross.iloc[i,][cross.iloc[i,]==1].shape[0]-1):
            #temp = pd.DataFrame(columns=('ORG1','ORG2','Count')
            temp = {'ORG1':ff.index[j], 'ORG2':ff.index[k], 'Count':1}
            dff = dff.append(temp,ignore_index=True)
dffmeet = dff

writedf.drop(writedf.columns[0],1)
ts = writedf
tt = ts[ts.write==1]
tt.groupby('GroupID')
cross = pd.crosstab(tt.GroupID,tt.ORG)
dff = pd.DataFrame(columns=('ORG1','ORG2','Count'))
for i in range(0,cross.shape[0]):
#for i in range(17,18):
    ff = pd.DataFrame(cross.iloc[i,][cross.iloc[i,]==1])
    for j in range(0,cross.iloc[i,][cross.iloc[i,]==1].shape[0]-1):
        for k in range(0,cross.iloc[i,][cross.iloc[i,]==1].shape[0]-1):
            #temp = pd.DataFrame(columns=('ORG1','ORG2','Count')
            temp = {'ORG1':ff.index[j], 'ORG2':ff.index[k], 'Count':1}
            dff = dff.append(temp,ignore_index=True)
dffwrite = dff

projdf.drop(projdf.columns[0],1)
ts = projdf
tt = ts[ts.proj==1]
tt.groupby('GroupID')
cross = pd.crosstab(tt.GroupID,tt.ORG)
dff = pd.DataFrame(columns=('ORG1','ORG2','Count'))
for i in range(0,cross.shape[0]):
#for i in range(17,18):
    ff = pd.DataFrame(cross.iloc[i,][cross.iloc[i,]==1])
    for j in range(0,cross.iloc[i,][cross.iloc[i,]==1].shape[0]-1):
        for k in range(0,cross.iloc[i,][cross.iloc[i,]==1].shape[0]-1):
            #temp = pd.DataFrame(columns=('ORG1','ORG2','Count')
            temp = {'ORG1':ff.index[j], 'ORG2':ff.index[k], 'Count':1}
            dff = dff.append(temp,ignore_index=True)
dffproj = dff

otherdf.drop(otherdf.columns[0],1)
ts = otherdf
tt = ts[ts.other==1]
tt.groupby('GroupID')
cross = pd.crosstab(tt.GroupID,tt.ORG)
dff = pd.DataFrame(columns=('ORG1','ORG2','Count'))
for i in range(0,cross.shape[0]):
#for i in range(17,18):
    ff = pd.DataFrame(cross.iloc[i,][cross.iloc[i,]==1])
    for j in range(0,cross.iloc[i,][cross.iloc[i,]==1].shape[0]-1):
        for k in range(0,cross.iloc[i,][cross.iloc[i,]==1].shape[0]-1):
            #temp = pd.DataFrame(columns=('ORG1','ORG2','Count')
            temp = {'ORG1':ff.index[j], 'ORG2':ff.index[k], 'Count':1}
            dff = dff.append(temp,ignore_index=True)
dffother = dff

readdf.drop(readdf.columns[0],1)
ts = readdf
tt = ts[ts.read==1]
tt.groupby('GroupID')
cross = pd.crosstab(tt.GroupID,tt.ORG)
dff = pd.DataFrame(columns=('ORG1','ORG2','Count'))
for i in range(0,cross.shape[0]):
#for i in range(17,18):
    ff = pd.DataFrame(cross.iloc[i,][cross.iloc[i,]==1])
    for j in range(0,cross.iloc[i,][cross.iloc[i,]==1].shape[0]-1):
        for k in range(0,cross.iloc[i,][cross.iloc[i,]==1].shape[0]-1):
            #temp = pd.DataFrame(columns=('ORG1','ORG2','Count')
            temp = {'ORG1':ff.index[j], 'ORG2':ff.index[k], 'Count':1}
            dff = dff.append(temp,ignore_index=True)
dffread = dff

dffread['task']='read'
dffemail['task']='email'
dffmeet['task']='meet'
dffproj['task']='proj'
dffwrite['task']='write'
dffother['task']='other'
dffevent['task']='event'
#dffother.append(dffwrite.append(dffevent.append(dffproj.append(dffmeet.append(dffread.append(dffemail))))))

# %%
import numpy as np

# %%
(smat[dffother['ORG1'][10]].loc[dffother['ORG2'][10]])
# Out:
# 0

# %%
o1 = dffother['ORG1'][10]

# %%
smat = pd.DataFrame(index =unique(df['ORG']), columns=unique(df['ORG']))
smat = smat.fillna(0)

# %%
for i in xrange(0,dffother.shape[0]-1):
    oo = dffother['ORG1'][i]
    of = dffother['ORG2'][i]
    s = (smat[oo].loc[of])
    smat[dffother['ORG1'][i]].loc[dffother['ORG2'][i]] = s+1

for i in xrange(0,dffread.shape[0]-1):
    oo = dffread['ORG1'][i]
    of = dffread['ORG2'][i]
    s = (smat[oo].loc[of])
    smat[dffread['ORG1'][i]].loc[dffread['ORG2'][i]] = s+1

for i in xrange(0,dffwrite.shape[0]-1):
    oo = dffwrite['ORG1'][i]
    of = dffwrite['ORG2'][i]
    s = (smat[oo].loc[of])
    smat[dffwrite['ORG1'][i]].loc[dffwrite['ORG2'][i]] = s+1

for i in xrange(0,dffproj.shape[0]-1):
    oo = dffproj['ORG1'][i]
    of = dffproj['ORG2'][i]
    s = (smat[oo].loc[of])
    smat[dffproj['ORG1'][i]].loc[dffproj['ORG2'][i]] = s+1

for i in xrange(0,dffmeet.shape[0]-1):
    oo = dffmeet['ORG1'][i]
    of = dffmeet['ORG2'][i]
    s = (smat[oo].loc[of])
    smat[dffmeet['ORG1'][i]].loc[dffmeet['ORG2'][i]] = s+1

for i in xrange(0,dffemail.shape[0]-1):
    oo = dffemail['ORG1'][i]
    of = dffemail['ORG2'][i]
    s = (smat[oo].loc[of])
    smat[dffemail['ORG1'][i]].loc[dffemail['ORG2'][i]] = s+1

# %%
smat.to_csv("//Users/TScott/Google Drive/elwha/ExactMatchDirectParticipation.csv")

# %%
smat
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 217 entries, Adopt-a-Stream Foundation to Wolf Hollow Wildlife Rehabilitation Center
# Columns: 217 entries, Adopt-a-Stream Foundation to Wolf Hollow Wildlife Rehabilitation Center
# dtypes: object(217)

# %%
dffproj.shape
# Out:
# (19356, 4)

# %%
#smat.loc['Pierce County']
smat['Pierce County'].loc['Pierce County']
# Out:
# nan

# %%
smat.iloc[0:10,0:10]
# Out:
# ORG                                 Adopt-a-Stream Foundation  \
# ORG
# Adopt-a-Stream Foundation                                   7
# Association of Washington Cities                            0
# Bainbridge Beach Naturalists                                0
# Bainbridge Island Watershed Council                         0
# Chambers/Clover Watershed Council                           1
# Chico Creek Task Force                                      0
# Citizens for a Healthy Bay                                  0
# Citizens of Orcas Island                                    0
# City of Arlington                                           0
# City of Bainbridge Island                                   0
#
# ORG                                 Association of Washington Cities  \
# ORG
# Adopt-a-Stream Foundation                                          0
# Association of Washington Cities                                   5
# ...
